# %%
import pandas as pd
import time
import requests

# ==========================
# OLLAMA CONFIG
# ==========================
OLLAMA_URL = "http://localhost:11434/api/generate"
MODEL_NAME = "qwen2.5:7b"


def call_ollama(prompt, max_new_tokens=512, temperature=0.7, top_p=0.9):
    payload = {
        "model": MODEL_NAME,
        "prompt": prompt,
        "options": {
            "temperature": temperature,
            "top_p": top_p,
            "num_predict": max_new_tokens
        },
        "stream": False
    }

    response = requests.post(OLLAMA_URL, json=payload)
    if response.status_code != 200:
        raise RuntimeError(f"Ollama API error: {response.text}")

    data = response.json()
    return data.get("response", "").strip()


# ==========================
# Load CSV
# ==========================
OUTPUT_FILE = "agents_free_stance_qwen2.csv"
backgrounds = pd.read_csv("agent_backgrounds.csv")
topics = pd.read_csv("topics.csv")


# ==========================
# Free stance + model generates its own 1–5 preference
# ==========================
def run_agent(bg, topic_row):

    identity = (
        f"You are {bg['age']} years old, {bg['gender']}, "
        f"from {bg['region']}, working as a {bg['occupation']}."
    )
    statement = topic_row["statement"]

    prompt = f"""
You are writing fiction and role-playing a fictional character:
{identity}

Statement to respond to:
"{statement}"

Your stance is NOT fixed.  
Choose your own stance freely based on the character’s background.

Write the answer in this structure:

Reason 1: ...
Reason 2: ...
Reason 3: ...
Summary: ...

Then output a final line:
Preference: X

Where:
• X is an integer from 1 to 5  
• 1 = strongly disagree  
• 2 = somewhat disagree  
• 3 = neutral/mixed  
• 4 = somewhat agree  
• 5 = strongly agree  
• The number must reflect the stance shown in your Reasons and Summary  
• DO NOT pick a random number — derive it logically from your own answer

[CONTENT RULES]
• 80–120 English words  
• Each Reason = 1–2 sentences  
• Reasons must reflect the character's age, job, region, and culture  
• No repetition or vague statements

[SUMMARY RULES]
• Must follow logically from the reasons  
• Must reuse at least one concrete idea  
• Must NOT introduce new arguments
""".strip()

    response = call_ollama(prompt)

    return {
        "topic_id": topic_row["topic_id"],
        "statement": statement,
        "age": bg["age"],
        "gender": bg["gender"],
        "region": bg["region"],
        "occupation": bg["occupation"],
        "model_response": response,
    }


# ==========================
# Main generator
# ==========================
def generate_agents(n_per_topic=6):
    results = []

    for _, topic_row in topics.iterrows():
        print(f"\n=== Topic {topic_row['topic_id']}: {topic_row['statement']} ===")

        for i in range(n_per_topic):
            bg = backgrounds.sample(n=1).iloc[0]
            record = run_agent(bg, topic_row)
            results.append(record)
            print(f"✓ Agent {i+1}/{n_per_topic} done")
            time.sleep(0.2)

    df = pd.DataFrame(results)
    df.to_csv(OUTPUT_FILE, index=False)
    print(f"\nSaved {len(df)} rows to {OUTPUT_FILE}.")
    return df


# ==========================
# Run
# ==========================
df_final = generate_agents(n_per_topic=30)
# Out:
# === Topic 1: Taxes help to meet the needs of society. ===
# ✓ Agent 1/30 done
# ✓ Agent 2/30 done
# ✓ Agent 3/30 done
# ✓ Agent 4/30 done
# ✓ Agent 5/30 done
# ✓ Agent 6/30 done
# ✓ Agent 7/30 done
# ✓ Agent 8/30 done
# ✓ Agent 9/30 done
# ✓ Agent 10/30 done
# ✓ Agent 11/30 done
# ✓ Agent 12/30 done
# ✓ Agent 13/30 done
# ✓ Agent 14/30 done
# ✓ Agent 15/30 done
# ✓ Agent 16/30 done
# ✓ Agent 17/30 done
# ✓ Agent 18/30 done
# ✓ Agent 19/30 done
# ✓ Agent 20/30 done
# ✓ Agent 21/30 done
# ✓ Agent 22/30 done
# ✓ Agent 23/30 done
# ✓ Agent 24/30 done
# ✓ Agent 25/30 done
# ✓ Agent 26/30 done
# ✓ Agent 27/30 done
# ✓ Agent 28/30 done
# ✓ Agent 29/30 done
# ✓ Agent 30/30 done
#
# === Topic 2: Immigration is a benefit to our country. ===
# ✓ Agent 1/30 done
# ✓ Agent 2/30 done
# ✓ Agent 3/30 done
# ✓ Agent 4/30 done
# ✓ Agent 5/30 done
# ✓ Agent 6/30 done
# ✓ Agent 7/30 done
# ✓ Agent 8/30 done
# ✓ Agent 9/30 done
# ✓ Agent 10/30 done
# ✓ Agent 11/30 done
# ✓ Agent 12/30 done
# ...

# %%
import pandas as pd
import time
import requests

# ==========================
# OLLAMA CONFIG
# ==========================
OLLAMA_URL = "http://localhost:11434/api/generate"
MODEL_NAME = "llama3.1:latest"


def call_ollama(prompt, max_new_tokens=512, temperature=0.7, top_p=0.9):
    payload = {
        "model": MODEL_NAME,
        "prompt": prompt,
        "options": {
            "temperature": temperature,
            "top_p": top_p,
            "num_predict": max_new_tokens
        },
        "stream": False
    }

    response = requests.post(OLLAMA_URL, json=payload)
    if response.status_code != 200:
        raise RuntimeError(f"Ollama API error: {response.text}")

    data = response.json()
    return data.get("response", "").strip()


# ==========================
# Load CSV
# ==========================
OUTPUT_FILE = "agents_free_stance_llama3.csv"
backgrounds = pd.read_csv("agent_backgrounds.csv")
topics = pd.read_csv("topics.csv")


# ==========================
# Free stance + model generates its own 1–5 preference
# ==========================
def run_agent(bg, topic_row):

    identity = (
        f"You are {bg['age']} years old, {bg['gender']}, "
        f"from {bg['region']}, working as a {bg['occupation']}."
    )
    statement = topic_row["statement"]

    prompt = f"""
You are writing fiction and role-playing a fictional character:
{identity}

Statement to respond to:
"{statement}"

Your stance is NOT fixed.  
Choose your own stance freely based on the character’s background.

Write the answer in this structure:

Reason 1: ...
Reason 2: ...
Reason 3: ...
Summary: ...

Then output a final line:
Preference: X

Where:
• X is an integer from 1 to 5  
• 1 = strongly disagree  
• 2 = somewhat disagree  
• 3 = neutral/mixed  
• 4 = somewhat agree  
• 5 = strongly agree  
• The number must reflect the stance shown in your Reasons and Summary  
• DO NOT pick a random number — derive it logically from your own answer

[CONTENT RULES]
• 80–120 English words  
• Each Reason = 1–2 sentences  
• Reasons must reflect the character's age, job, region, and culture  
• No repetition or vague statements

[SUMMARY RULES]
• Must follow logically from the reasons  
• Must reuse at least one concrete idea  
• Must NOT introduce new arguments
""".strip()

    response = call_ollama(prompt)

    return {
        "topic_id": topic_row["topic_id"],
        "statement": statement,
        "age": bg["age"],
        "gender": bg["gender"],
        "region": bg["region"],
        "occupation": bg["occupation"],
        "model_response": response,
    }


# ==========================
# Main generator
# ==========================
def generate_agents(n_per_topic=6):
    results = []

    for _, topic_row in topics.iterrows():
        print(f"\n=== Topic {topic_row['topic_id']}: {topic_row['statement']} ===")

        for i in range(n_per_topic):
            bg = backgrounds.sample(n=1).iloc[0]
            record = run_agent(bg, topic_row)
            results.append(record)
            print(f"✓ Agent {i+1}/{n_per_topic} done")
            time.sleep(0.2)

    df = pd.DataFrame(results)
    df.to_csv(OUTPUT_FILE, index=False)
    print(f"\nSaved {len(df)} rows to {OUTPUT_FILE}.")
    return df


# ==========================
# Run
# ==========================
df_final = generate_agents(n_per_topic=30)
# Out:
# === Topic 1: Taxes help to meet the needs of society. ===
# ✓ Agent 1/30 done
# ✓ Agent 2/30 done
# ✓ Agent 3/30 done
# ✓ Agent 4/30 done
# ✓ Agent 5/30 done
# ✓ Agent 6/30 done
# ✓ Agent 7/30 done
# ✓ Agent 8/30 done
# ✓ Agent 9/30 done
# ✓ Agent 10/30 done
# ✓ Agent 11/30 done
# ✓ Agent 12/30 done
# ✓ Agent 13/30 done
# ✓ Agent 14/30 done
# ✓ Agent 15/30 done
# ✓ Agent 16/30 done
# ✓ Agent 17/30 done
# ✓ Agent 18/30 done
# ✓ Agent 19/30 done
# ✓ Agent 20/30 done
# ✓ Agent 21/30 done
# ✓ Agent 22/30 done
# ✓ Agent 23/30 done
# ✓ Agent 24/30 done
# ✓ Agent 25/30 done
# ✓ Agent 26/30 done
# ✓ Agent 27/30 done
# ✓ Agent 28/30 done
# ✓ Agent 29/30 done
# ✓ Agent 30/30 done
#
# === Topic 2: Immigration is a benefit to our country. ===
# ✓ Agent 1/30 done
# ✓ Agent 2/30 done
# ✓ Agent 3/30 done
# ✓ Agent 4/30 done
# ✓ Agent 5/30 done
# ✓ Agent 6/30 done
# ✓ Agent 7/30 done
# ✓ Agent 8/30 done
# ✓ Agent 9/30 done
# ✓ Agent 10/30 done
# ✓ Agent 11/30 done
# ✓ Agent 12/30 done
# ...
